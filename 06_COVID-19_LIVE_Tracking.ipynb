# %%
import pandas as pd

df = pd.read_json('https://www.mohfw.gov.in/data/datanew.json')

df.head()
# Out:
#    sno                   state_name  active  positive   cured  death  \
# 0    2  Andaman and Nicobar Islands     172      3848    3623     53
# 1    1               Andhra Pradesh   57858    700235  636508   5869
# 2    3            Arunachal Pradesh    2955     10020    7049     16
# 3    4                        Assam   34163    182396  147522    711
# 4    5                        Bihar   12086    184038  171048    904
#
#    new_active  new_positive  new_cured  new_death state_code
# 0         174          3858       3631         53         35
# 1       56897        706790     643993       5900         28
# 2        3019         10220       7183         18         12
# 3       34128        183812     148963        721         18
# 4       12077        185436     172449        910         10

# %%
df = df.iloc[:-1,1:]

# %%
df.head()
# Out:
#                     state_name  active  positive   cured  death  new_active  \
# 0  Andaman and Nicobar Islands     172      3848    3623     53         174
# 1               Andhra Pradesh   57858    700235  636508   5869       56897
# 2            Arunachal Pradesh    2955     10020    7049     16        3019
# 3                        Assam   34163    182396  147522    711       34128
# 4                        Bihar   12086    184038  171048    904       12077
#
#    new_positive  new_cured  new_death state_code
# 0          3858       3631         53         35
# 1        706790     643993       5900         28
# 2         10220       7183         18         12
# 3        183812     148963        721         18
# 4        185436     172449        910         10

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
total_states = np.arange(len(df['state_name']))

# %%
sum(df['active'])
# Out:
# 942217

# %%
max(df['positive'])
# Out:
# 1400922

# %% [markdown]
# #### Total Positive Cases Based on States in INDIA

# %%
from matplotlib.pyplot import figure

figure(num=None, figsize=(9,6), dpi=80, facecolor='w', edgecolor='k')
plt.barh(total_states, df['positive'], align='center', alpha=0.5, color=(1,0,0), edgecolor=(0.5,0.2,0.8))
plt.yticks(total_states, df['state_name'])
plt.xlim(1, max(df['positive'])+100)
plt.xlabel('Positive Number of Cases')
plt.title('Corona Virus Cases')
plt.show()

# %% [markdown]
# #### Active Number of Cases based on States

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(9, 6), dpi=80, facecolor='w', edgecolor='k')
plt.barh(total_states,df['new_active'], align='center', alpha=0.5,  
                 color=(1,0.5,0),  
                 edgecolor=(0.5,0.4,0.8)  )
    
plt.yticks(total_states, df['state_name'])  
plt.xlim(1,max(df['new_active'])+10) 
plt.xlabel('Active Number of Cases')  
plt.title('Corona Virus Cases')  
plt.show()
